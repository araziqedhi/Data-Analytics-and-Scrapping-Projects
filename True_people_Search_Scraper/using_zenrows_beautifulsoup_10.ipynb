# %%
import pandas as pd
import urllib.parse
from bs4 import BeautifulSoup
from zenrows import ZenRowsClient
import re

# Read the DataFrame from the provided Excel file
df = pd.read_excel("./Project EXCEL FAST PEOPLE SEARCH (2).xlsx")

# Create an empty DataFrame to store the URLs
url_df = pd.DataFrame(columns=['URL'])

# Iterate over the rows of the DataFrame
for index, row in df.iterrows():
    # Get the address components from the DataFrame
    street_address = row['Mailing Address']
    city = row['Mailing City']
    state = row['Mailing State']
    
    # Format the address components for the URL
    formatted_street_address = urllib.parse.quote(street_address)
    formatted_citystatezip = urllib.parse.quote(f"{city},{state}")
    
    # Construct the URL
    url = f"https://www.truepeoplesearch.com/resultaddress?streetaddress={formatted_street_address}&citystatezip={formatted_citystatezip}"
    
    # Create a temporary DataFrame for the URL
    temp_df = pd.DataFrame({'URL': [url]})
    
    # Concatenate the temporary DataFrame with the main DataFrame
    url_df = pd.concat([url_df, temp_df], ignore_index=True)

# Save the DataFrame to a CSV file
url_df.to_csv("urls.csv", index=False)

# Create a ZenRowsClient instance
client = ZenRowsClient("840911f2101dafeeb3b4c3f882bd083d4673a02e")

# Create an empty list to store the matched records
matched_records = []

# Iterate over the URLs in 'url_df' and compare with the corresponding entries in the 'short_data (1) (2)' DataFrame
for index, row in url_df.iterrows():
    url = row['URL']
    params = {"premium_proxy": "true"}
    
    try:
        # Perform the request to fetch the HTML content
        response = client.get(url, params=params)
        response.raise_for_status()  # Check for any HTTP errors
        
        # Assume `html` contains the HTML content of the page
        html = response.text
        
        # Parse the HTML using BeautifulSoup
        soup = BeautifulSoup(html, 'html.parser')
        
        # Find all <div> elements with class="col-md-8"
        div_col_md_8_list = soup.find_all('div', class_='col-md-8')
        
        # Extract the text from each <div> element with class="h4" inside the <div class="col-md-8">
        h4_texts = []
        for div_col_md_8 in div_col_md_8_list:
            h4_div = div_col_md_8.find('div', class_='h4')
            if h4_div is not None:
                h4_text = h4_div.get_text().strip()
                h4_texts.append(h4_text)
        
        # Find all elements with the data-detail-link attribute
        elements = soup.find_all(attrs={'data-detail-link': True})
        
        # Extract the href attribute from each element
        links = []
        for element in elements:
            href_link = element.get('data-detail-link')
            links.append(href_link)
        
        # Create a dictionary with the extracted data
        data = {
            "Name": h4_texts,
            "Link": links
        }
        
        # Create the DataFrame for the extracted data
        df_extracted = pd.DataFrame(data)
        
        # Get the corresponding entry from the 'short_data (1) (2)' DataFrame
        df_short_data_entry = df.loc[index]

        # Get the first name from the 'short_data (1) (2)' DataFrame entry and strip whitespaces
        owner1_first_name = df_short_data_entry['Owner 1 First Name']
        if not isinstance(owner1_first_name, float):
            owner1_first_name = owner1_first_name.strip()
        else:
            owner1_first_name = "Not found"
        
        owner2_first_name = df_short_data_entry['Owner 2 First Name']
        if not isinstance(owner2_first_name, float):
            owner2_first_name = owner2_first_name.strip()
        else:
            owner2_first_name = "Not found"

        # Filter the extracted DataFrame to match the first name
        if owner1_first_name and not isinstance(owner1_first_name, float):
            # Filter using regular expression to match the first name
            regex = re.compile(r"\b" + re.escape(owner1_first_name.lower()) + r"\b")
            df_matched_records = df_extracted[df_extracted['Name'].str.lower().str.contains(regex)]
        elif owner2_first_name:
            # Filter using regular expression to match the first name
            regex = re.compile(r"\b" + re.escape(owner2_first_name.lower()) + r"\b")
            df_matched_records = df_extracted[df_extracted['Name'].str.lower().str.contains(regex)]
        else:
            print("Not found")
            df_matched_records = pd.DataFrame(columns=["Name", "Link"])  # Create an empty DataFrame

        # Print the matched records to check
        print(f"Extracted Data for URL {index}:\n{df_extracted}")
        print(f"Matched Records for URL {index}:\n{df_matched_records}")

        # Append the matched records to the main list
        matched_records.append(df_matched_records)
        
    except Exception as e:
        # If there's an error with the current URL, handle it here
        # You can print an error message or log the error for further analysis
        print(f"Error occurred for URL {index}: {e}")
        # You can choose to skip this URL and continue with the next one, or take any other appropriate action

# Concatenate all matched records into the final DataFrame
df_final = pd.concat(matched_records, ignore_index=True)

# Print the matched records and the final DataFrame
print("Matched Records:")
print(df_final)

df_final.to_csv("./final_links.csv")

# Rest of the code...
# (Continue with the rest of the program as before)
# Out:
# Extracted Data for URL 0:
#                   Name                                Link
# 0   Bonnie J McCartney   /find/person/pnl6469849ru6l04n00u
# 1   Beverly J Johnston  /find/person/px6u2n8rl0l022n026042
# 2         Levi G Burns  /find/person/pxlu244u88ru4n68n48ul
# 3      Mark Levi Baird   /find/person/pnu9uuu69244ull6u440
# 4  Phillip D McCartney   /find/person/p69rn0r042u42uru8096
# 5  Richard P McCartney   /find/person/pxr688uln6rr88229424
# Matched Records for URL 0:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 1:
#                   Name                                Link
# 0    Deirdre F Johnson  /find/person/px2490l4unnl8lrr9866n
# 1         Renee H Munz   /find/person/p2484r24222ll2800r89
# 2       William J Munz    /find/person/p2269u06266n22llun4
# 3    David P Cooprider    /find/person/p4ln2nlrl66nr220009
# 4   Lillie J Cooprider   /find/person/p448n860u242ur0n02r2
# 5   Francisco R Garcia   /find/person/pn942r4unnrnn90n8nnl
# 6         William Manz  /find/person/pxlr9048nl9uu299n8urn
# 7     Francisco Garcia   /find/person/p2288928440ll6nnr0l6
# 8  Carol Ann Gutierrez   /find/person/pl8r9l0494442rn26229
# 9   Francisco R Garcia  /find/person/px4r9l9ul9r2u4ur98626
# Matched Records for URL 1:
#            Name                               Link
# 1  Renee H Munz  /find/person/p2484r24222ll2800r89
# Extracted Data for URL 2:
#                   Name                                Link
# 0    Anthony J Cheston  /find/person/pxnu242lun0uu06946r98
# 1       Dora M Cheston   /find/person/px82r9unr94u66nn49r6
# 2        Myra A Aquino  /find/person/pxn828nln964unun99n84
# 3        Erich Heubach   /find/person/pn2l2902lu04428ul48n
# 4      Carlos L Aquino   /find/person/prr62u8u986u200892u6
# 5       Patricia Smith  /find/person/pxu6r04rul0404n946n68
# 6        Shane S Smith   /find/person/px4940uuuu8n2u89uluu
# 7  Lourdes M Fernandez   /find/person/p9l262l68406rl2r40u6
# Matched Records for URL 2:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 3:
#                     Name                                Link
# 0      William E Collado  /find/person/pxl290rl8r6066r2l4u8n
# 1       Carlos E Sanchez   /find/person/p68n968u4l9n4460l4l0
# 2       Leonor C Sanchez  /find/person/pxnuu96n4622946lrlr42
# 3         Leonor Sanchez   /find/person/px2u6l4226828949ln2n
# 4        Luis Valderrama  /find/person/px480lulr429r46r0489r
# 5        Ligia A Collado   /find/person/pnll48r4l626l2480nr2
# 6      Zoneida Agramonte   /find/person/p4u06l66l860n6l64962
# 7        Aydee C Collado  /find/person/px6l9r6n080098ll909n0
# 8  Mercedes D Valderrama  /find/person/px4624nl9rn4428nnnn99
# 9     Robert P Riemersma   /find/person/prrl0unu0628rr499nun
# Matched Records for URL 3:
#                 Name                                Link
# 0  William E Collado  /find/person/pxl290rl8r6066r2l4u8n
# Extracted Data for URL 4:
#                 Name                                Link
# 0     Bernice Wooten  /find/person/pxun0u26uun99lr04926n
# 1    Dexter Campbell    /find/person/pxn669n82260r8nl6r8
# 2   Doretha Campbell   /find/person/p828u8499808r9n26l8r
# 3  Adrian T Williams  /find/person/pxl9l6ll0r06n8r9l2rr0
# 4    Javin D Jackson  /find/person/pxl4unru6nl96686249uu
# 5    James Burroughs   /find/person/p84n469lr2r8llu94uln
# 6  Melvin A Williams  /find/person/px4946n604rl2nn660un9
# 7     Aliza L Cotton  /find/person/px400424nu09249rr26u2
# 8      John Campbell  /find/person/pxrr2l8null448u4r62u9
# 9    John D Williams   /find/person/pr92l686u99r9996l6n9
# Matched Records for URL 4:
#              Name                                Link
# 0  Bernice Wooten  /find/person/pxun0u26uun99lr04926n
# Extracted Data for URL 5:
#                 Name                                Link
# 0     Hudson Demetry  /find/person/px840un40r929r6u22l8l
# 1    Carlton C Jones   /find/person/p628u968806l9ru80660
# 2     Chantel Hudson   /find/person/pnl0r2r02n289u928lu9
# 3        Eddie Jones  /find/person/px4ull48lr49r4l4r0url
# 4     Susie Spurlock  /find/person/px824u2n44u848r006u08
# 5      Atonia Hudson   /find/person/p694l09rl6uu99640l6r
# 6  Henry C Christian   /find/person/p898ll6444ru6unr06l8
# 7     Wilda M Julias   /find/person/p2rl9886uu8l094n6666
# 8    Terencio Julias  /find/person/px86l0u69l9444r6842n9
# 9     Zonnie C Jones  /find/person/pxrnn292r82404ru6l0nn
# Matched Records for URL 5:
#               Name                               Link
# 1  Carlton C Jones  /find/person/p628u968806l9ru80660
# Extracted Data for URL 6:
#                    Name                                Link
# 0      Trajauna Johnson   /find/person/p2rrn4208rl0r84r9l6l
# 1          Emma D Paulk   /find/person/p4n68l6n64nnul8n9n09
# 2      Daniel J Radford   /find/person/plu6896l0624ulunll9n
# 3  Dondrick M Roundtree  /find/person/pxunnrn69r00ln84n4890
# 4        Darryn Wortham   /find/person/p49l4n0448r999404220
# 5        Jeremy Johnson   /find/person/pln9lur0n40nr6402rll
# 6        Aufrey Radford   /find/person/pnl2uur849r68rrr2r84
# 7       Andrea Bradford   /find/person/px484924086l620r89u6
# 8      Taurus D Radford  /find/person/px6n02l64l4r4240u8020
# 9      Audrey F Radford  /find/person/px4u69nn62u9r6u8u88nn
# Matched Records for URL 6:
#            Name                               Link
# 1  Emma D Paulk  /find/person/p4n68l6n64nnul8n9n09
# Extracted Data for URL 7:
#                  Name                                Link
# 0     David R Thacker   /find/person/p2l9ruu4u0098062nl8u
# 1    Sue Hawks Foster   /find/person/p2024006u949nll0l66l
# 2     Trudy M Thacker  /find/person/pxl29u4nu9urnn429llrl
# 3          John Davis  /find/person/px4l2uu08r2ll0n28n29u
# 4     Kevin Czaplicki  /find/person/pxl02nuun989u0n6ll96u
# 5   Nora M Michelotti  /find/person/px8n49n8l64rr60r0l890
# 6     Armon B Coleman  /find/person/pxn06l40nn90904n68r92
# 7    John W Chrzaszcz  /find/person/px66lrn6ru4n00u6nnl24
# 8  Calvin D Thirdrick   /find/person/pu02u9n8200900n0unun
# Matched Records for URL 7:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 8:
#                  Name                                Link
# 0   James L Lacouture   /find/person/p2lu62nl906nnrn4r962
# 1    Rufina Lacouture   /find/person/p49408l222r68r2r0nu9
# 2   Alberto Lacouture  /find/person/pxn684rr2u24l0966r262
# 3       David R Evans   /find/person/plr660nurlll86209849
# 4  Xavier J Lacouture   /find/person/pun6990rnr20n40l2298
# 5      Ronald F Burth   /find/person/p60urn90rnu2ru804nn9
# 6     Richard C Evans   /find/person/p2604nu6lul28l98nnrr
# 7     Dorothy G Evans    /find/person/p66028l9nu9ul00ul4r
# Matched Records for URL 8:
#                 Name                               Link
# 0  James L Lacouture  /find/person/p2lu62nl906nnrn4r962
# Extracted Data for URL 9:
#                        Name                                Link
# 0           Jerline S Weems   /find/person/p698r8rr4n00n90r9r22
# 1            Cedric J Weems  /find/person/pxlu48r690689l488u262
# 2               Jerry Weems  /find/person/pxu66u6002rr4062892l2
# 3              Cedric Weems   /find/person/p4rruu9rn69u26024068
# 4            Brian S Watson   /find/person/pu00824rllu809n8229n
# 5            Victoria Weems  /find/person/pxl0lunn86rn9944rlun8
# 6           Tquana Matthews    /find/person/pu2nr0920ur20296n86
# 7           Shantell Watson   /find/person/pn944u09r424n640u86u
# 8  Willie Wealth McCullough   /find/person/puln0ln4u66nnuur6620
# Matched Records for URL 9:
#               Name                               Link
# 0  Jerline S Weems  /find/person/p698r8rr4n00n90r9r22
# Extracted Data for URL 10:
#                 Name                                Link
# 0     Connie W Seals  /find/person/px29r62u6989rln4l2200
# 1  Judith A Dietrich   /find/person/p6nl29n4l96nun909r08
# 2      Brian J Seals    /find/person/pxl0urnr224n66r6r0u
# 3    Hailey S Bexley   /find/person/p668480u40u44ul866rr
# 4   Jeremeika Pierce    /find/person/p2ur99042094r868l0l
# 5  Javid N Murray Jr   /find/person/p892r2884n868n904968
# 6      Mark T Etting   /find/person/p22ur84l4r0n488nr4l0
# Matched Records for URL 10:
#              Name                                Link
# 0  Connie W Seals  /find/person/px29r62u6989rln4l2200
# Extracted Data for URL 11:
#                 Name                                Link
# 0  Michelle D Koster  /find/person/px82n2996ull944ru60n2
# 1  Richard R Melnick  /find/person/px4280l46l9649n9rnr02
# 2     Bennie Tillman   /find/person/p2nn899l09929lrrlr6u
# 3      Billy J Weeks  /find/person/pxr9l8n4ll4u9nl096990
# 4   Jeffrey S Koster  /find/person/pxrr28289r899r098rnnn
# 5   Victoria F Fiori  /find/person/px22u6uu2ulnn0r698629
# Matched Records for URL 11:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 12:
#                   Name                                Link
# 0     Daniel R Sanchez    /find/person/p224624248u24l486l4
# 1     Angela Y Sanchez  /find/person/px6nnl9nl9n6n0l99080r
# 2     Briana A Sanchez  /find/person/pxu8r62ru80u28r292u20
# 3     Joshua G Sanchez   /find/person/pl088099u9lu0nlr6u48
# 4         Luis Sanchez   /find/person/pxnuu099lu6n2846l6n0
# 5    Elaine T Williams  /find/person/pxn0r9884u48094n4r4l2
# 6         Luis Persaud   /find/person/p46669lur04rrun0n08l
# 7     Samantha Morales  /find/person/px244u00449u0u9r2969r
# 8         Rose Morales   /find/person/pr68498904800l4n2u60
# 9  Luis Thomas Sanchez  /find/person/px488l9982un8un9999r9
# Matched Records for URL 12:
#                   Name                                Link
# 4         Luis Sanchez   /find/person/pxnuu099lu6n2846l6n0
# 6         Luis Persaud   /find/person/p46669lur04rrun0n08l
# 9  Luis Thomas Sanchez  /find/person/px488l9982un8un9999r9
# Extracted Data for URL 13:
#                    Name                                Link
# 0          John W Bader  /find/person/pxlr6lr680nln80luur9u
# 1        Joseph R Perry   /find/person/pll9284489ln0n406286
# 2  Carlos Alfredo Perez  /find/person/pxnnn9n66rnu2u0nn660l
# 3        Ashlyn Leonard  /find/person/pxuru09nnrl26n94r249n
# 4          Regina Bader  /find/person/pxll8n280n08l429l4r0l
# 5        Regina M Bader   /find/person/p628lrrl2nrrln2r68r4
# 6        Leona T Coffey  /find/person/px6l90090unrurr64046n
# 7          Paul Fiedler  /find/person/px40u2828048l20686829
# 8      Terry D Sakowicz  /find/person/px48944n8ur9640n6r6u4
# 9       Angel Garcia Jr  /find/person/px8nu966rn408699rn40l
# Matched Records for URL 13:
#            Name                                Link
# 0  John W Bader  /find/person/pxlr6lr680nln80luur9u
# Extracted Data for URL 14:
#                 Name                                Link
# 0   Viktoria Collins  /find/person/px4l80r0rn4946r8u8u2l
# 1   Julian Estupinan   /find/person/pnu9rl0u442r06099049
# 2    Victor Santiago  /find/person/pxuuur8nr468nn46n4440
# 3     Natalie D Hall  /find/person/px8l9460808008068u0nn
# 4     Robinson Nunez    /find/person/p9l694nn6r49ru9u480
# 5   Joseph C Sims Jr   /find/person/pr80r48r9469986rrru9
# 6   Michael D Miller  /find/person/pxn4ln664l6426r8r2n98
# 7  Deborah A Freddie  /find/person/pxl80n40ul0llrun40u68
# 8         Thuy Huynh  /find/person/px499r0uu0nu4n48l86n4
# 9       Sarah K Hill   /find/person/p48n9r469unl84n9u949
# Matched Records for URL 14:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 15:
#                      Name                                Link
# 0               Hodge Shy  /find/person/pxur82600n84n2rru0l2u
# 1     Nathaniel Arnold Jr  /find/person/pxn24rlnl0lll9662n298
# 2       Capria L Crawford   /find/person/pn8992nu6nlrul8r0l6l
# 3          Eugenia S Knox   /find/person/px62r60620049n42n8n0
# 4    Shuntilley Hodge Shy  /find/person/pxr9080r9948924lu6ulu
# 5  Annette Arnold Y Lewis   /find/person/p2ll6u4n62u260nll0r0
# 6         Jimmie J Arnold  /find/person/px84r080lrn8l86n02804
# 7        Nathaniel Arnold   /find/person/pr8l92n4n66669860269
# 8     Earnestine R Arnold  /find/person/px48640rl6rurunl48820
# 9     Nathaniel Arnold Sr   /find/person/pl098ln09890nn2l9682
# Matched Records for URL 15:
#                   Name                                Link
# 1  Nathaniel Arnold Jr  /find/person/pxn24rlnl0lll9662n298
# 7     Nathaniel Arnold   /find/person/pr8l92n4n66669860269
# 9  Nathaniel Arnold Sr   /find/person/pl098ln09890nn2l9682
# Extracted Data for URL 16:
#                  Name                                Link
# 0  Sophia H Wondergem  /find/person/pxluun09lu4260r8nuunl
# 1     Stephanie Geyer  /find/person/pxnl02l42000l9440nnr9
# 2  Thomas W Wondergem  /find/person/px89rl498l02n0r49nnrl
# 3    Sophia Wondergem   /find/person/p2n889n02u260r2486r0
# 4      Bobbi Jo Hanek   /find/person/p4r69ul462u9n989466r
# 5   James W Wondergem  /find/person/px4lrn22624n2r402u0nn
# 6   Daniell L Weekley   /find/person/px6869u9ll62uu666u2l
# 7  Vernon H Parkes Jr  /find/person/px908n9u248626urrln6r
# 8      Isaiah C Davis    /find/person/pu29r026l98ln2nl2u8
# 9       Vivien Hannah  /find/person/px840r8rlu96464l2l4ll
# Matched Records for URL 16:
#                  Name                                Link
# 0  Sophia H Wondergem  /find/person/pxluun09lu4260r8nuunl
# 3    Sophia Wondergem   /find/person/p2n889n02u260r2486r0
# Extracted Data for URL 17:
#                   Name                                Link
# 0    Judith S Thompson  /find/person/pxn09406uur242l8846l2
# 1  Lynette R Fernandez  /find/person/pxrr4urllr29l0l666908
# 2       Nedra E Womack  /find/person/pxnu6u2u2r8620l8n8284
# 3      Donnie G Womack   /find/person/pr62r6uuunr96ln6962l
# 4       Sidney Thompso   /find/person/pxr84n62l99099r0r24u
# 5     Denise S Gattuso  /find/person/px4ll999r09u44980n2u2
# 6       Diane L Foster    /find/person/prn9nu6n984048224u6
# 7      Patrick Gattuso  /find/person/px9l09n6nn40994l64984
# 8           Sarah Mack   /find/person/p822l4646u09l2n8ll48
# 9      Sidney Thompson   /find/person/p69649r9u0ru88n64u94
# Matched Records for URL 17:
#               Name                               Link
# 4   Sidney Thompso  /find/person/pxr84n62l99099r0r24u
# 9  Sidney Thompson  /find/person/p69649r9u0ru88n64u94
# Extracted Data for URL 18:
#                Name                                Link
# 0  William C Hughes  /find/person/px6n842u626rr2986u966
# 1      Jasmin Ponce   /find/person/p49029r4l62nnl8l96n4
# 2       Nilsa Otero  /find/person/pxu46u84rr69rn8u8n62n
# 3    Reynaldo Gomez   /find/person/pl8nn8n208nr2nl9698u
# 4       Robert Roth   /find/person/p80u4r9nn6u860692940
# 5  Ryan P Churchill  /find/person/px6nr0u266299l0nlu204
# 6  Armando Martinez  /find/person/pxl04n02629469lllr82l
# 7  Charles D Rogers  /find/person/pxuru4n62n48u9nl8rr22
# 8        Jacky Diaz   /find/person/p6rl844229r89l488l20
# 9   Soraya Martinez   /find/person/px492l9unrr84869n084
# Matched Records for URL 18:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 19:
#                  Name                                Link
# 0    Noreen H Shields  /find/person/pxr6898n0n22rn292n022
# 1   Richard D Shields  /find/person/pxruu8ur8l800u0nr44n9
# 2    Henry G Smernoff   /find/person/prrr9u064l626u00u64u
# 3      Noelle Shields   /find/person/p4u8809u02n0u9026r2n
# 4      Rita P Fleming   /find/person/pl802l66ll640r406400
# 5        Paul N Klein    /find/person/pl998ln8rrrn89900ul
# 6  Beverly M Smernoff   /find/person/p4l4l4294rr4url444r8
# Matched Records for URL 19:
#                Name                                Link
# 0  Noreen H Shields  /find/person/pxr6898n0n22rn292n022
# Extracted Data for URL 20:
#                     Name                                Link
# 0           Rose Gardner  /find/person/px6n80428988rlulu4run
# 1  Charity Tenesia Jones  /find/person/px249n694u4n99n96n0n0
# 2    Katrina L Mc Fadden  /find/person/px209nlnlll6n0u090l2n
# 3             Henry Wade   /find/person/p42n6l908l40044949ln
# 4     Demetrick McFadden   /find/person/pul0r698802248u4l6lr
# 5         Calvin M Fagen   /find/person/p8r264ur66424l6r92rr
# 6            Travis Ward  /find/person/pxur802r922n09lnunu24
# 7          Larry D Jones  /find/person/px28rl668l64r942urun0
# 8         Calvin M Fagan  /find/person/px44r6lu4rn2n996l9rur
# 9            Jay S Jones    /find/person/pn6ru244r42n668600r
# Matched Records for URL 20:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 21:
#                      Name                                Link
# 0           Rose M Mattia   /find/person/pnunn9n8222lnl2082r6
# 1             Iris Denham   /find/person/plnu0r49lrrr6n6r9u42
# 2             Tj S Denham  /find/person/px608989uu9n4u92u020r
# 3          Mark B Kennedy  /find/person/pxr6rr00r4nnn8r68r4r0
# 4         Santiago J Vera   /find/person/p8n400r8l4n8690094n9
# 5          Barbara Pulido   /find/person/pnnrnnul6nuu948ru826
# 6        Salvatore Morena  /find/person/pxru849lunlnl2l2lr8n6
# 7  Christian P Larriviere   /find/person/p28u822u04906u2nl890
# 8             Rosa V Vera   /find/person/p4294rl44r24nrur2l86
# Matched Records for URL 21:
#             Name                               Link
# 0  Rose M Mattia  /find/person/pnunn9n8222lnl2082r6
# Extracted Data for URL 22:
#                      Name                                Link
# 0              Lee Waters  /find/person/px8rrl9r80r8966n2209u
# 1           Scott Trikina   /find/person/purr469l0920u40ll2l9
# 2          Taren R Cotton   /find/person/p4r42260802l4l9886n9
# 3           Keshia Waters  /find/person/px808r28n086n960rrl8l
# 4            Lamarr Brown   /find/person/p6nr8080n2022l966449
# 5  Mikela Wynnielle Tatum   /find/person/p222lrlr9u9840lu8689
# 6         John H Williams   /find/person/p48r222694u8068u4u9r
# 7            Taren Cotton   /find/person/px99u96uuru96rul9428
# 8         Lakeshia Waters   /find/person/p28l808466r4400ur866
# 9          Courtney Brown  /find/person/px409nl2nl209r8ur48n4
# Matched Records for URL 22:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 23:
#                   Name                                Link
# 0        Martha M Lott   /find/person/p80460290220828un8l9
# 1    Sparkman Christle   /find/person/p6096ulu942u6nn69u99
# 2    Sylvester Lott Jr  /find/person/pxrur64nrr980llnrr404
# 3       Sylvester Lott  /find/person/px9lr028l68r8n8n424l4
# 4          Sylvia Lott  /find/person/pxu69r0406l996u0990l2
# 5       Delia Sparkman   /find/person/p2uuln2nr9n2u680urrl
# 6          Sylvia Lott   /find/person/p2028r02nrr06r24uu9l
# 7       Rachel Pittman  /find/person/px8nn9l9ln9629046902l
# 8        Paul Prescott  /find/person/px89u6r2ul9rnn899lu24
# 9  Percy P Williams Sr   /find/person/pn6266nl49869uu20ur4
# Matched Records for URL 23:
#             Name                               Link
# 0  Martha M Lott  /find/person/p80460290220828un8l9
# Extracted Data for URL 24:
#                 Name                                Link
# 0  Ruben D Mendez Sr  /find/person/pxur4lrl99n906nlr96l0
# 1       Julio E Ruiz   /find/person/p66url22nu9l4484n446
# 2   Leemarie Fuentes   /find/person/p8u8908l699ur2n2ln40
# 3   Kimberly K Cheek   /find/person/prlu80rnn8nnr248nlul
# 4   Travis W Mattson  /find/person/px490r9ulul4rnn002uru
# 5   Carmen J Mendoza  /find/person/pxnl2n069llr26n69r26n
# 6        Dakota Lynn  /find/person/px248r888nn2n2unuu209
# 7    Rebecca Sandler  /find/person/pxlr46u9n6n6r080nn2nu
# 8     Jordan Huggins  /find/person/pxnln2run28l98rl062lr
# 9     Matthew Mendez    /find/person/pnl90l20u44909n6944
# Matched Records for URL 24:
#                 Name                                Link
# 0  Ruben D Mendez Sr  /find/person/pxur4lrl99n906nlr96l0
# Extracted Data for URL 25:
#                   Name                                Link
# 0       Kelly L Kinard   /find/person/p448rnr269r4un0n690n
# 1     Juanita C Kinard   /find/person/pn42nu6rr8l80r902842
# 2     Charles E Kinard   /find/person/pr8904494nl8lunrnn42
# 3  Charles E Kinard Jr   /find/person/px98u2l8u4l282842498
# 4     Timothy S Kinard   /find/person/pn9r84nrnu8nun6llln4
# 5    Kristina L Kinard   /find/person/plu4l4r6ln086r069u28
# 6      Arlene M Sylvia   /find/person/p60042r2280ll2u98426
# 7       Amy Willoughby   /find/person/p2nn84208nn0nu4u46n8
# 8         Edward Myers   /find/person/p262ll4u24069u422228
# 9     Charles D Kinard  /find/person/px40u4n0u80n689r9rn96
# Matched Records for URL 25:
#                Name                               Link
# 4  Timothy S Kinard  /find/person/pn9r84nrnu8nun6llln4
# Extracted Data for URL 26:
#                   Name                                Link
# 0          Dexter Neal   /find/person/pun09u46964009u94u90
# 1        Don L Edwards  /find/person/px206l66988l99l44ul89
# 2   Kelvin D Burney Jr   /find/person/pl66u294ulrnr422n86u
# 3       Saking Johnson   /find/person/p6828nl0urn64ul2u49r
# 4  Matthew Dorsey Ross   /find/person/pr2l6l99229lul28602r
# 5      Marcus B Dorsey  /find/person/pxlru08nnrn282r06r200
# 6        Jenny Johnson  /find/person/pxln204u440n490u926rn
# 7      Ricardo M Valle  /find/person/px86l9nun2ullnu842608
# 8           Karen Ford   /find/person/p6n8n68806n8lnn4u484
# Matched Records for URL 26:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 27:
#                  Name                                Link
# 0    Carmen C Pena Sr   /find/person/pn0449ln99n9999n0u2r
# 1      Francisco Pena   /find/person/p469lrr60lrlr209u890
# 2         Juan M Pena  /find/person/px890u0l29llr86680ru9
# 3       Etelvino Pena   /find/person/p8r448r962nl2n6rn0rl
# 4      Francisco Bena   /find/person/p4860u8rn46428488002
# 5        Ramon N Pena   /find/person/p2rl99040ln00un849nn
# 6     George L Copley  /find/person/pxn446n4n92096946un22
# 7     William Jenkins  /find/person/px2r2lu2ln24r6u848l9u
# 8  Elizabeth A Copley  /find/person/px6uu0un6urn6990280n2
# 9         Carmen Pena   /find/person/pnullr0r46ln662r9nun
# Matched Records for URL 27:
#                Name                               Link
# 0  Carmen C Pena Sr  /find/person/pn0449ln99n9999n0u2r
# 9       Carmen Pena  /find/person/pnullr0r46ln662r9nun
# Extracted Data for URL 28:
#                     Name                                Link
# 0       Heidi A Milliken   /find/person/prr4lrr0u6unnnlru4n8
# 1       David E Milliken   /find/person/p49l0n692690l2n86908
# 2    James I Milliken Sr  /find/person/px6l60n068ll4rlrl9649
# 3       Heidi A Milliken   /find/person/pxn29nu0r282u69ll969
# 4  Daniel J Christiansen  /find/person/pxnnl6l8l9l9rl628ru06
# 5    Beverly Jean Hughes   /find/person/p8r290l2r84l00u0u0ll
# Matched Records for URL 28:
#                Name                               Link
# 1  David E Milliken  /find/person/p49l0n692690l2n86908
# Extracted Data for URL 29:
#                Name                                Link
# 0  Patricia A Johns  /find/person/pxrnn0rl829r4u8lu9490
# 1       Mark S Ruiz   /find/person/p4u24lll4n06u9nu0n20
# 2     David J Allen  /find/person/px4r9822l66un404n299n
# 3        Todd Casey  /find/person/pxl46ln96l88l8n2rr94u
# 4        Jacob Todd   /find/person/pu06ll4n8u404r28ln8u
# 5        Jacob Todd  /find/person/px4u928ull498ul6n990u
# 6   Kaileigh D Dean   /find/person/p4llr04l4l84rr690u80
# 7   Sandra D Garvey  /find/person/pxl848lnuu89n8989n42l
# 8     Jessie Garvey   /find/person/pn022090l98l682464ru
# 9       Kristi Todd   /find/person/pn4u06ll2n88269862u6
# Matched Records for URL 29:
#               Name                                Link
# 7  Sandra D Garvey  /find/person/pxl848lnuu89n8989n42l
# Extracted Data for URL 30:
#                   Name                                Link
# 0         Eston R Dunn   /find/person/pl6n02rr0u9l6n9r6ru0
# 1  Michael K Weisbrodt   /find/person/p88r8n9044u08629nu06
# 2      Louise L Daniel    /find/person/p9r2u46r02u6n94l0r6
# 3    Dunnout Write Inc   /find/person/p642n92r6rru0u0n628r
# 4      William J Green  /find/person/pxul8nr6lrr48un9l680l
# 5     Frankie Ambriose    /find/person/p4urr68242url80264r
# 6      Muguette Joseph  /find/person/pxnr8r82lrurl2n942998
# 7        Jeanne M Alix  /find/person/pxl6024968020rl4024r0
# 8      Wadson Sagaille   /find/person/p4842922u2lrnrlr9uln
# 9    Jonathan Cherilus   /find/person/pn0u6264ul99ln8n6904
# Matched Records for URL 30:
#                   Name                               Link
# 1  Michael K Weisbrodt  /find/person/p88r8n9044u08629nu06
# Extracted Data for URL 31:
#                  Name                                Link
# 0  Deborah A Sheppard   /find/person/pl068r904nr2l0uu9rln
# 1      Ben G Sheppard  /find/person/px9069nll44ulul90ru69
# 2   Charlotte A Grose  /find/person/pxln62r2nu6u99r94822r
# 3      Kerry C Huelle  /find/person/pxr90r9r99904ur82nl09
# 4        Andrew D Bos   /find/person/p2rr8n92022l089n2u60
# 5      Ben F Sheppard   /find/person/p2n89unnlrnn4994ll68
# 6      Paul D Trawick  /find/person/px88446496l4rl8429rr2
# 7     Faye S Sheppard   /find/person/p24unl664r609828uu60
# Matched Records for URL 31:
#              Name                                Link
# 1  Ben G Sheppard  /find/person/px9069nll44ulul90ru69
# 5  Ben F Sheppard   /find/person/p2n89unnlrnn4994ll68
# Extracted Data for URL 32:
#                Name                                Link
# 0  Brentin M Carter   /find/person/p68ur864lu0n4n088849
# 1     Tori Franklin  /find/person/pxlll8n866242ll8884n2
# 2     Dnina V Lyons  /find/person/pxl68uu82nr499l06u00l
# 3    Pamela R Lyons   /find/person/p64u08l24ur6u6n964n2
# 4  Raymond Lyonsiii  /find/person/pxr20r96n8nu66r26u4ll
# 5    Minnie M Lyons   /find/person/p4rlr908086n88ulr22l
# 6    Lashonda Smith   /find/person/p646nl48r2n2nl28994r
# 7    Anotonio Lyons  /find/person/px46nr206628rurlulnu9
# 8    Antonino Lyons   /find/person/pru9unr0942l8r00l820
# 9     Tori Franklin  /find/person/px66nl0r6n04l02908299
# Matched Records for URL 32:
#             Name                                Link
# 2  Dnina V Lyons  /find/person/pxl68uu82nr499l06u00l
# Extracted Data for URL 33:
#                     Name                                Link
# 0        Nelson E Dunham  /find/person/pxn90l8l0820r08r84r9l
# 1        Daniel E Dunham   /find/person/pn0r989990uulrl2nu9r
# 2           Ann E Dunham  /find/person/px49ur209uu442460rlun
# 3    Bernie L Solomon Jr  /find/person/px2nrur80920604l9286r
# 4       Heather R Dunham   /find/person/pul9484uu6r692466rrr
# 5  Bernie Lee Solomon Jr   /find/person/pu994nu696l46n966nl2
# 6          Diane Martino    /find/person/pr9ru8u49r84rru4rr4
# 7        Cammy T Burkett   /find/person/p6r9229924nrurl92024
# 8        William Burkett  /find/person/pxll096r40nu8940rn069
# Matched Records for URL 33:
#               Name                                Link
# 0  Nelson E Dunham  /find/person/pxn90l8l0820r08r84r9l
# Extracted Data for URL 34:
#                   Name                                Link
# 0        James P Conte   /find/person/p88r66n09969u24lllrn
# 1    Victoria S Beaver    /find/person/p4l08u94242rr2l92u4
# 2      Brian L Daniels  /find/person/pxlrl8l99688r62r96660
# 3      Heather V Conte   /find/person/pr0un282lll8ur8nlrun
# 4     Cynthia B Hammen  /find/person/px200luu49499lr4ll44u
# 5  Velma L Whittington   /find/person/prl08u6ul2n0n44nnlr6
# 6      Brian C Daniels  /find/person/px6442422040rnu9ulnn2
# 7     Brenda J Daniels   /find/person/p84nlnnr099lu029u080
# 8   Robert O Armstrong  /find/person/px4629l04020nu0l0l9u4
# 9     Raymond D Daniel  /find/person/px2996u04ur49442r009u
# Matched Records for URL 34:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 35:
#                         Name                                Link
# 0          Michelle D Melton  /find/person/px88280444l606u4uunr8
# 1          Shahaan A Bennett    /find/person/p2n2408r499n9002008
# 2              Louis R Clark   /find/person/p8484000080runr80luu
# 3       Precious D Alexander  /find/person/pxrlrlnn6n889944n2n98
# 4       Precious D Alexander   /find/person/p6426489440u4rnrr609
# 5                Keith Oneal   /find/person/pulr244849896864r4ru
# 6         Precious Alexander   /find/person/pn9l06u04l608nn4nn0l
# 7          Shantavia Frazier   /find/person/prl9uru0lrnlnu04r809
# 8  Vernice Frazier Shantavia   /find/person/p2lnnl0u266n06u894rn
# Matched Records for URL 35:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 36:
#                   Name                                Link
# 0    Nerilanda Destave   /find/person/pxnu9n9n4r9nu60l0028
# 1    Alyssa Richardson   /find/person/pnr08n9ru92662luu8l9
# 2     Gricel M Navarro  /find/person/pxrlnu4946829ul9n8696
# 3     Monica G Rosales   /find/person/pln888l26nn4rrnun986
# 4     Marianne Laurent  /find/person/px6uu29rn00r92u298nrl
# 5      Nerilan Destave   /find/person/p8r494ul2r2n284u9n0n
# 6  Alyssa M Richardson   /find/person/p42n246l48l8n60r2nr2
# 7    Andrea Richardson   /find/person/pun669l0l8n80l08l04r
# 8      Kenson Previlon  /find/person/px8l929nunn42lu4lr2un
# 9     Lazaro J Navarro   /find/person/pxru464rruur04r89942
# Matched Records for URL 36:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 37:
#                  Name                                Link
# 0  Paulette D Malcolm  /find/person/pxnul2l0262946l906994
# 1    Glenford Malcolm  /find/person/px8nu909l02226888r9u4
# 2    Kikolisa Johnson   /find/person/pll48u4668r49n8r0ur9
# 3    Glenford Malcolm  /find/person/px44r4ruur8228ur099r9
# 4    Dieujuste Bryton   /find/person/pun8r004904r0r694l64
# 5    Elaine Varrialle   /find/person/pu29484084ll9nl9n869
# 6    Kikolisa Johnson   /find/person/p20828n962u06nlr04n6
# Matched Records for URL 37:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 38:
#               Name                                Link
# 0   Joan Hernandez   /find/person/p2rnu06n440u294l949n
# 1   Anicett F Diaz   /find/person/pr4uu86694nlul444869
# 2   Rosendo D Diaz   /find/person/pllulu909u8rl4l0n9nn
# 3   Rosendo J Diaz  /find/person/px80849440ln98u2n40nn
# 4  Anna D Gargiulo  /find/person/pxln98nlun9u969u8n668
# 5     Orlando Diaz  /find/person/px6689u68l2649nunn0u6
# Matched Records for URL 38:
#              Name                               Link
# 1  Anicett F Diaz  /find/person/pr4uu86694nlul444869
# Extracted Data for URL 39:
#                 Name                                Link
# 0     Samantha Lopez  /find/person/px4u0r2runu228r6n4929
# 1   Belkis M Herrera   /find/person/pnr909r0u484nr8l864n
# 2    Michael Struber  /find/person/px86nr84l00nu0lu44lll
# 3   Belkis M Malgoza   /find/person/pn26n046un92n6u4lrr4
# 4        Ana Herrera  /find/person/px426l0lulurlu99ul84l
# 5   Samantha Herrera  /find/person/pxn44u24604rlu960996r
# 6    Matilde Alvarez  /find/person/pxrl0869llrur4l0n9r2u
# 7  Michael N Struber   /find/person/p2l2ru864u6nrrru94l2
# 8     Marta Castillo  /find/person/pxur669986lnn446u240l
# 9  Michael N Malgoza   /find/person/pn94u6n4rr64lr2r829l
# Matched Records for URL 39:
#                Name                               Link
# 1  Belkis M Herrera  /find/person/pnr909r0u484nr8l864n
# 3  Belkis M Malgoza  /find/person/pn26n046un92n6u4lrr4
# Extracted Data for URL 40:
#                 Name                                Link
# 0       Ralph Cooper    /find/person/pr4996l0ll688lnl94u
# 1      Sharon Thomas   /find/person/pu9l424u22n9nr4640ul
# 2     Chanese Cooper    /find/person/p444un2ur24u08ln90l
# 3    Vivian W Cooper  /find/person/px64nnlnu869u029nrrn2
# 4      Curtis Mungin  /find/person/pxunu6n2l6rn20696rn2u
# 5    Pythia C Mathis    /find/person/pr48298u064l428r806
# 6     Cynthia Cooper  /find/person/px4489l4r6nlr62u480n8
# 7    Derrick Hepburn    /find/person/p66ll9244r9n4r2uu62
# 8  Ralph V Cooper Jr  /find/person/pxn94u28r9ru042l0urlr
# 9       Ralph Cooper   /find/person/pu460u222l9ur424960r
# Matched Records for URL 40:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 41:
#                Name                                Link
# 0      Arelis Ramos   /find/person/p820u04l2rn29u04u8r6
# 1       Ana J Limas   /find/person/pu4rr2l6400rr2lrunnl
# 2      Milda Garcia  /find/person/pxul62l68l46nn9l9rn82
# 3    Enrique Justiz   /find/person/pnn2nrrn244l2l06u428
# 4       Irma Uviera   /find/person/p4l0n8r08600069ulunn
# 5    Tyrone Kilgore  /find/person/px8r8828nr6l888l02288
# 6    Lucina J Claro   /find/person/p4004809nn89n0u264ru
# 7     Jacobo Garcia   /find/person/p2l9ll0648r8n4l2rrr2
# 8  Heather R Sasner  /find/person/pxrn8r882289urll248ul
# 9  Josefina Peralta   /find/person/p80609l80u6n6l246444
# Matched Records for URL 41:
#            Name                                Link
# 2  Milda Garcia  /find/person/pxul62l68l46nn9l9rn82
# Extracted Data for URL 42:
#                 Name                                Link
# 0   Floderia D Parms   /find/person/pn06nun808lr0896l0nn
# 1     Samuel J Smith   /find/person/p68uru4l4u4lr9n80640
# 2      Billy Journey  /find/person/px9ll4l6ululnnlu28426
# 3  Cornelius A Parms  /find/person/pxn62ur684n8n8n80r9nu
# 4       Lillie Parms  /find/person/px2lru88rr42286rlu8r8
# 5    Malvenia Martin  /find/person/px24l640r6n482960nr64
# 6      Flozell Parms  /find/person/px2lu8820nu84n4u4r2rl
# 7     Maggie E Lloyd   /find/person/p806nnu99rurru8ulu80
# 8     Armetta Whymss  /find/person/px62u682l4406868249l8
# 9   Lillian J Thomas   /find/person/p26nu4l0684886u842un
# Matched Records for URL 42:
#                Name                               Link
# 0  Floderia D Parms  /find/person/pn06nun808lr0896l0nn
# Extracted Data for URL 43:
#                 Name                                Link
# 0          Alvi Pozo   /find/person/pn6088ll99rl62u62r6l
# 1    Humberto Maseda  /find/person/pxnr292268606r2un986l
# 2  Renee D Spaulding   /find/person/p2lrr8uu02r296222r80
# 3       Anthony Moss   /find/person/p494n40u2uur24u4l2r8
# 4      Juan J Maseda  /find/person/pxl8804r2894466nurn40
# 5      Marcos A Ruiz  /find/person/px48n6rn909980l82822n
# 6        Ruben Ozuna  /find/person/pxl9n4690208lunr0840l
# 7   Michael L Debose  /find/person/pxu64998464n69u09l04n
# 8        Sara Bailey  /find/person/px268l29l28u0n9u94uu2
# 9    Cyril C Rahming   /find/person/p22n90r2r8r484r86n8r
# Matched Records for URL 43:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 44:
#                     Name                                Link
# 0         Abbie E Klosky   /find/person/prr89n2n82nn4u2rnn90
# 1  Millicent D Rothstein  /find/person/px4r92488ur8l9l6uulr4
# 2      Lawrence H Klosky   /find/person/px9646n60nr26ul90l42
# 3       Guillermo Valdez   /find/person/pn96n9ll44nnn980u840
# 4        Justin B Klosky    /find/person/p62ul42rnn86r8ll989
# 5          Chad A Klosky  /find/person/px696ru66lr604r2604nu
# 6     Anastasia Semenova  /find/person/pxn4n8222n48480nn2444
# 7        Henry Rothstein   /find/person/pn4l944498966049r460
# Matched Records for URL 44:
#              Name                               Link
# 0  Abbie E Klosky  /find/person/prr89n2n82nn4u2rnn90
# Extracted Data for URL 45:
#                     Name                                Link
# 0        Grady E Gilbert   /find/person/p24u2uu4lul08ru444rr
# 1          Holly Gilbert  /find/person/pxr20l4l42lr4668n8rlu
# 2        Holly G Gilbert  /find/person/px409ruulnl82rnr68849
# 3          Albert F Shaw  /find/person/px82922286u96u888r2n0
# 4        Mark A Peterson  /find/person/px606r8r968r0lrrnrlu6
# 5         Val M Peterson   /find/person/p6ll249l82unnru94l4l
# 6          Anna S Gibert   /find/person/p62lnn4nn09909626lu4
# 7        Amber C Gilbert  /find/person/px22r48490nn2l0nu9ul8
# 8        Jeffry Wilensky  /find/person/px4088nlr86n62r0lluu8
# 9  David Robert Levinson    /find/person/pu9488nr444u0r4r6n6
# Matched Records for URL 45:
# Empty DataFrame
# Columns: [Name, Link]
# Index: []
# Extracted Data for URL 46:
#                               Name                                Link
# 0                 Ralph J Bienaime   /find/person/pllrlulun6046u800u94
# 1                Kayla M Bien Aime   /find/person/pnnrll88ll4nnn6n6lu8
# 2              Francisco Maldonado  /find/person/pxun2ru66n8n2unu98r00
# 3                  Aime Kayla Bien  /find/person/px8r008u24l4l06n68rl6
# 4              Ralph J Bienaime Jr    /find/person/p8n44r0n0ur4l984nn0
# 5              Christopher E Perez  /find/person/pxnrlu92684nu2lr88uuu
# 6                 Ralph J Bienaime   /find/person/pu89988n6864r2u4l88u
# 7  Yessenia Sieliciana Ramos-colon  /find/person/pxrn686n20r6n0209r406
# 8                    Yanira Aviles  /find/person/pxun98n6r88024rl99082
# 9                     Mercy Alonso  /find/person/px6ln2r00u008286r22nu
# Matched Records for URL 46:
#                   Name                                Link
# 2  Francisco Maldonado  /find/person/pxun2ru66n8n2unu98r00
# Extracted Data for URL 47:
#                  Name                                Link
# 0   Virginia L Roland  /find/person/px4822n94n484n890868r
# 1    Sulaiman B Smith  /find/person/pxlun0486lnunu40r9r00
# 2       Soloman Smith  /find/person/pxn4r0224284u6rur6lru
# 3    Hannah M Johnson  /find/person/pxn22u29828ur98u46unr
# 4       Lula B Roland  /find/person/pxn04l42l266224u8u2n2
# 5     Richard E Smith  /find/person/pxuulru2089llrll6n00l
# 6  James L Vickers Sr  /find/person/px2n9lulrr0rn969908nu
# 7    George J Johnson   /find/person/px266ur44r29r694ulu4
# 8     Lilly M Vickers    /find/person/pr4998900888n24l9lr
# 9      Dottilda Small   /find/person/pr6n02l9r26rr4880ln8
# Matched Records for URL 47:
#               Name                                Link
# 5  Richard E Smith  /find/person/pxuulru2089llrll6n00l
# Extracted Data for URL 48:
#                   Name                                Link
# 0      Nadia N Johnson   /find/person/px669r848n46n42r62l0
# 1   Phillip D Griffith   /find/person/pu2089n6n44202ru4ln2
# 2    Ezekiel D Johnson   /find/person/p9l0u0r8ru42lu02l6l6
# 3      Anthony Johnson   /find/person/pun29u684nn4296unl68
# 4        James Rowland   /find/person/pu82942u6r0r0n4lnr0r
# 5        Anton G Gayle   /find/person/prr49u209696ll096464
# 6        Judy B Oneale  /find/person/pxll2nr60u8u4u02r0ll0
# 7  Stephanie A Rowland  /find/person/px6906u8u8020u0989r06
# 8      Stephan G Gayle     /find/person/p844l66nr94u6040rn
# 9           Enid Pryce   /find/person/pr44248l899u42u4ll2l
# Matched Records for URL 48:
#               Name                               Link
# 0  Nadia N Johnson  /find/person/px669r848n46n42r62l0
# Matched Records:
#                    Name                                Link
# 0          Renee H Munz   /find/person/p2484r24222ll2800r89
# 1     William E Collado  /find/person/pxl290rl8r6066r2l4u8n
# 2        Bernice Wooten  /find/person/pxun0u26uun99lr04926n
# 3       Carlton C Jones   /find/person/p628u968806l9ru80660
# 4          Emma D Paulk   /find/person/p4n68l6n64nnul8n9n09
# 5     James L Lacouture   /find/person/p2lu62nl906nnrn4r962
# 6       Jerline S Weems   /find/person/p698r8rr4n00n90r9r22
# 7        Connie W Seals  /find/person/px29r62u6989rln4l2200
# 8          Luis Sanchez   /find/person/pxnuu099lu6n2846l6n0
# 9          Luis Persaud   /find/person/p46669lur04rrun0n08l
# 10  Luis Thomas Sanchez  /find/person/px488l9982un8un9999r9
# 11         John W Bader  /find/person/pxlr6lr680nln80luur9u
# 12  Nathaniel Arnold Jr  /find/person/pxn24rlnl0lll9662n298
# 13     Nathaniel Arnold   /find/person/pr8l92n4n66669860269
# 14  Nathaniel Arnold Sr   /find/person/pl098ln09890nn2l9682
# 15   Sophia H Wondergem  /find/person/pxluun09lu4260r8nuunl
# 16     Sophia Wondergem   /find/person/p2n889n02u260r2486r0
# 17       Sidney Thompso   /find/person/pxr84n62l99099r0r24u
# 18      Sidney Thompson   /find/person/p69649r9u0ru88n64u94
# 19     Noreen H Shields  /find/person/pxr6898n0n22rn292n022
# 20        Rose M Mattia   /find/person/pnunn9n8222lnl2082r6
# 21        Martha M Lott   /find/person/p80460290220828un8l9
# 22    Ruben D Mendez Sr  /find/person/pxur4lrl99n906nlr96l0
# 23     Timothy S Kinard   /find/person/pn9r84nrnu8nun6llln4
# 24     Carmen C Pena Sr   /find/person/pn0449ln99n9999n0u2r
# 25          Carmen Pena   /find/person/pnullr0r46ln662r9nun
# 26     David E Milliken   /find/person/p49l0n692690l2n86908
# 27      Sandra D Garvey  /find/person/pxl848lnuu89n8989n42l
# 28  Michael K Weisbrodt   /find/person/p88r8n9044u08629nu06
# 29       Ben G Sheppard  /find/person/px9069nll44ulul90ru69
# 30       Ben F Sheppard   /find/person/p2n89unnlrnn4994ll68
# 31        Dnina V Lyons  /find/person/pxl68uu82nr499l06u00l
# 32      Nelson E Dunham  /find/person/pxn90l8l0820r08r84r9l
# 33       Anicett F Diaz   /find/person/pr4uu86694nlul444869
# 34     Belkis M Herrera   /find/person/pnr909r0u484nr8l864n
# 35     Belkis M Malgoza   /find/person/pn26n046un92n6u4lrr4
# 36         Milda Garcia  /find/person/pxul62l68l46nn9l9rn82
# 37     Floderia D Parms   /find/person/pn06nun808lr0896l0nn
# 38       Abbie E Klosky   /find/person/prr89n2n82nn4u2rnn90
# 39  Francisco Maldonado  /find/person/pxun2ru66n8n2unu98r00
# 40      Richard E Smith  /find/person/pxuulru2089llrll6n00l
# 41      Nadia N Johnson   /find/person/px669r848n46n42r62l0

# %%
# Read the 'final_url' DataFrame from the CSV file and set the index to be the first column
final_url = pd.read_csv("./final_links.csv", index_col=0)

# Drop the 'Name' column from the DataFrame
final_url.drop("Name", axis=1, inplace=True)

# Add "https://www.truepeoplesearch.com" to each URL
final_url['Link'] = "https://www.truepeoplesearch.com" + final_url['Link']

# Print the updated DataFrame
print(final_url)

final_url.to_csv("./final_urls_ready.csv")
# Out:
#                                                  Link
# 0   https://www.truepeoplesearch.com/find/person/p...
# 1   https://www.truepeoplesearch.com/find/person/p...
# 2   https://www.truepeoplesearch.com/find/person/p...
# 3   https://www.truepeoplesearch.com/find/person/p...
# 4   https://www.truepeoplesearch.com/find/person/p...
# 5   https://www.truepeoplesearch.com/find/person/p...
# 6   https://www.truepeoplesearch.com/find/person/p...
# 7   https://www.truepeoplesearch.com/find/person/p...
# 8   https://www.truepeoplesearch.com/find/person/p...
# 9   https://www.truepeoplesearch.com/find/person/p...
# 10  https://www.truepeoplesearch.com/find/person/p...
# 11  https://www.truepeoplesearch.com/find/person/p...
# 12  https://www.truepeoplesearch.com/find/person/p...
# 13  https://www.truepeoplesearch.com/find/person/p...
# 14  https://www.truepeoplesearch.com/find/person/p...
# 15  https://www.truepeoplesearch.com/find/person/p...
# 16  https://www.truepeoplesearch.com/find/person/p...
# 17  https://www.truepeoplesearch.com/find/person/p...
# 18  https://www.truepeoplesearch.com/find/person/p...
# 19  https://www.truepeoplesearch.com/find/person/p...
# 20  https://www.truepeoplesearch.com/find/person/p...
# 21  https://www.truepeoplesearch.com/find/person/p...
# 22  https://www.truepeoplesearch.com/find/person/p...
# 23  https://www.truepeoplesearch.com/find/person/p...
# 24  https://www.truepeoplesearch.com/find/person/p...
# 25  https://www.truepeoplesearch.com/find/person/p...
# 26  https://www.truepeoplesearch.com/find/person/p...
# 27  https://www.truepeoplesearch.com/find/person/p...
# 28  https://www.truepeoplesearch.com/find/person/p...
# 29  https://www.truepeoplesearch.com/find/person/p...
# 30  https://www.truepeoplesearch.com/find/person/p...
# 31  https://www.truepeoplesearch.com/find/person/p...
# 32  https://www.truepeoplesearch.com/find/person/p...
# 33  https://www.truepeoplesearch.com/find/person/p...
# 34  https://www.truepeoplesearch.com/find/person/p...
# 35  https://www.truepeoplesearch.com/find/person/p...
# 36  https://www.truepeoplesearch.com/find/person/p...
# 37  https://www.truepeoplesearch.com/find/person/p...
# 38  https://www.truepeoplesearch.com/find/person/p...
# 39  https://www.truepeoplesearch.com/find/person/p...
# 40  https://www.truepeoplesearch.com/find/person/p...
# 41  https://www.truepeoplesearch.com/find/person/p...

# %%
# Read the DataFrame from the provided CSV file
url_df = pd.read_csv("./final_urls_ready.csv")

# Initialize empty lists to store the data
titles = []
ages = []
addresses = []  # Corrected list name
cities = []  # Add new list for city
states = []  # Add new list for state
zip_codes = []  # Add new list for zip code
home_specs = []  # Add new list for home specs
residential_areas = []  # Add new list for residential area
living_time_periods = []  # Add new list for living time period
phone_1=[]
phone_1_type=[]
phone_2=[]
phone_2_type=[]
phone_3=[]
phone_3_type=[]

# Iterate over the URLs in the DataFrame
for url in url_df['Link']:
    # Make a request using ZenRowsClient
    response = client.get(url, params=params)

    # Parse the HTML content using BeautifulSoup
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    elements = soup.find_all(class_="content-container container-fluid row pl-0 pr-0")
    if len(elements) >= 2:
        element2 = elements[1]
        element_depth = element2.find(class_="content-center")
        element_more_depth = element_depth.find(class_="card card-body shadow-form pt-2")
        element_more_more_depth = element_more_depth.find(class_="row pl-md-2")
        element_more_more_more_depth = element_more_more_depth.find(class_="col")

        title = element_more_more_more_depth.find("h1").get_text(strip=True) if element_more_more_more_depth else "Not found"
        age_text_list = [span.get_text(strip=True) for span in element_more_more_more_depth.find_all("span")] if element_more_more_more_depth else []
    else:
        title = "Not found"
        age_text_list = []

    address_element = soup.find('span', itemprop='streetAddress')

    # Get the text of the element (address) or set to "Not found" if element is not found
    address = address_element.get_text(strip=True) if address_element else "Not found"
    # Additional elements for city, state, zip code, home specs, area, living time period, and phone numbers
    city_element = soup.find('span', itemprop='addressLocality')
    city = city_element.get_text(strip=True) if city_element else "Not found"
    cities.append(city)

    state_element = soup.find('span', itemprop='addressRegion')
    state = state_element.get_text(strip=True) if state_element else "Not found"
    states.append(state)

    zip_element = soup.find('span', itemprop='postalCode')
    zip_code = zip_element.get_text(strip=True) if zip_element else "Not found"
    zip_codes.append(zip_code)
    
    home_specs_element = soup.find('span', class_="dt-sb")
    home_specs_value = home_specs_element.get_text(strip=True) if home_specs_element else "Not found"
    home_specs.append(home_specs_value)

    area_elements = soup.find_all('span', class_="dt-sb")
    residential_area = area_elements[1].get_text(strip=True) if len(area_elements) >= 2 else "Not found"
    residential_areas.append(residential_area)

    living_time_period = area_elements[2].get_text(strip=True) if len(area_elements) >= 3 else "Not found"
    living_time_periods.append(living_time_period)

    phone1_element = soup.find('span', itemprop='telephone')
    phone1 = phone1_element.get_text(strip=True) if phone1_element else "Not found"
    phone_1.append(phone1)

    phone_type_element = soup.find('span', class_="smaller")
    phone_type = phone_type_element.get_text(strip=True) if phone_type_element else "Not found"
    phone_1_type.append(phone_type)

    phone2_element = soup.find_all('span', itemprop='telephone')
    phone2 = phone2_element[1].get_text(strip=True) if len(phone2_element) >= 2 else "Not found"
    phone_2.append(phone2)

    phone2_type_element = soup.find_all('span', class_='smaller')
    phone2_type = phone2_type_element[1].get_text(strip=True) if len(phone2_type_element) >= 2 else "Not found"
    phone_2_type.append(phone2_type)

    phone3_element = soup.find_all('span', itemprop='telephone')
    phone3 = phone3_element[2].get_text(strip=True) if len(phone3_element) >= 3 else "Not found"
    phone_3.append(phone3)

    phone3_type_element = soup.find_all('span', class_='smaller')
    phone3_type = phone3_type_element[2].get_text(strip=True) if len(phone3_type_element) >= 3 else "Not found"
    phone_3_type.append(phone3_type)
    # Append the data to the lists
    addresses.append(address)  # Corrected list name
    titles.append(title)
    ages.append(", ".join(age_text_list))

# Create the DataFrame
df_finalized = pd.DataFrame({"Name": titles, "Age": ages, "Address": addresses,"City": cities,
    "State": states,
    "Zip Code": zip_codes,"Home Specs": home_specs,
    "Residential Area": residential_areas,
    "Living Time Period": living_time_periods,
                  "Phone1":phone_1,
                  "Phone1 Type":phone_1_type,
                  "Phone2":phone_2,
                  "Phone2 Type":phone_2_type,
                  "Phone3":phone_3,
                  "Phone3 Type":phone_3_type,})  # Added "Address" column

# Print the DataFrame

df_finalized.to_excel("./Ready data file.xlsx")

df_finalized
# Out:
#                    Name                                         Age  \
# 0          Renee H Munz                           Age 62 (Oct 1960)
# 1     William E Collado                           Age 75 (Jul 1947)
# 2        Bernice Wooten                                 Age Unknown
# 3       Carlton C Jones                           Age 46 (Feb 1977)
# 4          Emma D Paulk                           Age 76 (Apr 1947)
# 5     James L Lacouture                           Age 50 (Sep 1972)
# 6       Jerline S Weems                           Age 94 (Dec 1928)
# 7        Connie W Seals                           Age 76 (Jul 1946)
# 8          Luis Sanchez                           Age 52 (Nov 1970)
# 9          Luis Persaud                           Age 33 (Sep 1989)
# 10  Luis Thomas Sanchez                           Age 31 (Sep 1991)
# 11         John W Bader                           Age 34 (Mar 1989)
# 12  Nathaniel Arnold Jr                           Age 73 (Feb 1950)
# 13     Nathaniel Arnold                           Age 95 (Jul 1928)
# 14  Nathaniel Arnold Sr                           Age 94 (Aug 1928)
# 15   Sophia H Wondergem                           Age 76 (Dec 1946)
# 16     Sophia Wondergem                           Age 76 (Dec 1946)
# 17       Sidney Thompso                                 Age Unknown
# 18      Sidney Thompson                           Age 97 (Jan 1926)
# 19     Noreen H Shields                           Age 81 (Dec 1941)
# 20        Rose M Mattia                           Age 84 (Jan 1939)
# 21        Martha M Lott                           Age 57 (Feb 1966)
# 22    Ruben D Mendez Sr                           Age 54 (Dec 1968)
# 23     Timothy S Kinard                           Age 51 (Feb 1972)
# 24     Carmen C Pena Sr                           Age 75 (Jan 1948)
# 25          Carmen Pena                           Age 63 (Aug 1959)
# 26     David E Milliken                           Age 66 (Jan 1957)
# 27      Sandra D Garvey                           Age 56 (Jun 1967)
# 28  Michael K Weisbrodt                           Age 57 (Dec 1965)
# 29       Ben G Sheppard                           Age 77 (Mar 1946)
# 30       Ben F Sheppard  Death RecordMarch 2000(age 76), March 2000
# 31        Dnina V Lyons                           Age 33 (Dec 1989)
# 32      Nelson E Dunham                           Age 70 (Mar 1953)
# 33       Anicett F Diaz                           Age 92 (May 1931)
# 34     Belkis M Herrera                           Age 59 (Feb 1964)
# 35     Belkis M Malgoza                           Age 59 (Feb 1964)
# 36         Milda Garcia                           Age 91 (Dec 1931)
# 37     Floderia D Parms                           Age 67 (Sep 1955)
# 38       Abbie E Klosky                           Age 71 (Apr 1952)
# 39  Francisco Maldonado                           Age 48 (Nov 1974)
# 40      Richard E Smith                           Age 75 (Feb 1948)
# 41      Nadia N Johnson                           Age 43 (Aug 1979)
#
#                       Address               City State Zip Code  \
# 0            9055 SW 102nd Pl              Ocala    FL    34481
# 1        2534 10th Ave N #114         Lake Worth    FL    33461
# 2                1665 40th St    West Palm Beach    FL    33407
# 3              5422 Marcia Pl    West Palm Beach    FL    33407
# 4               1161 W 4th St      Riviera Beach    FL    33404
# 5              651 Everest Rd             Venice    FL    34293
# 6             8325 Endive Ave              Tampa    FL    33619
# 7   3108 W Ballast Point Blvd              Tampa    FL    33611
# 8            2709 N Morgan St              Tampa    FL    33602
# 9             919 S Heron Cir       Winter Haven    FL    33884
# 10     6727 S Lois Ave #12111              Tampa    FL    33616
# 11           204 Key Haven Rd           Key West    FL    33040
# 12             1150 W 25th St      Riviera Beach    FL    33404
# 13             1150 W 25th St      Riviera Beach    FL    33404
# 14           1963 Freeport Ln      Riviera Beach    FL    33404
# 15              2027 Mark Ave        Punta Gorda    FL    33950
# 16              2027 Mark Ave        Punta Gorda    FL    33950
# 17            23 Wildwood Trl      New Braunfels    TX    78130
# 18           704 Canyon Acres        Canyon Lake    TX    78133
# 19        3131 N Palm Aire Dr      Pompano Beach    FL    33069
# 20            7611 NW 14th St     Pembroke Pines    FL    33024
# 21            1017 NE 21st St        Belle Glade    FL    33430
# 22         2818 Picadilly Cir          Kissimmee    FL    34747
# 23           3855 Catalina St         Titusville    FL    32796
# 24           5043 Cassatt Ave            Orlando    FL    32808
# 25          140 Sunny Day Way          Davenport    FL    33897
# 26                PO Box 7774         North Port    FL    34290
# 27              13041 Ivy Ave           Etiwanda    CA    91739
# 28            240 NE 169th St  North Miami Beach    FL    33162
# 29     18600 State Route 93 S              Logan    OH    43138
# 30              2353 Howey Rd           Columbus    OH    43211
# 31         308 N Kentucky Ave              Cocoa    FL    32922
# 32           8339 Basalisk Ct    New Port Richey    FL    34653
# 33              PO Box 273837         Boca Raton    FL    33427
# 34           12600 SW 34th St              Miami    FL    33175
# 35           12600 SW 34th St              Miami    FL    33175
# 36            2530 NW 82nd St              Miami    FL    33147
# 37            2350 NW 58th St              Miami    FL    33142
# 38          7582 NW 127th Mnr           Parkland    FL    33076
# 39            2912 27th St SW       Lehigh Acres    FL    33976
# 40            4180 NW 26th St         Lauderhill    FL    33313
# 41              5739 Pine Ter         Plantation    FL    33317
#
#                                      Home Specs       Residential Area  \
# 0     2 Bed | 2 Bath | 1,328 Sq Ft | Built 1983          Marion County
# 1                             Palm Beach County  (Jan 2023 - Jul 2023)
# 2     3 Bed | 2 Bath | 2,135 Sq Ft | Built 1969      Palm Beach County
# 3                             Palm Beach County  (May 1995 - Jul 2023)
# 4     3 Bed | 2 Bath | 1,777 Sq Ft | Built 1981      Palm Beach County
# 5     3 Bed | 2 Bath | 1,060 Sq Ft | Built 1977        Sarasota County
# 6     2 Bed | 1 Bath | 1,084 Sq Ft | Built 1960    Hillsborough County
# 7     2 Bed | 1 Bath | 1,190 Sq Ft | Built 1960    Hillsborough County
# 8       2 Bed | 1 Bath | 896 Sq Ft | Built 1914    Hillsborough County
# 9     3 Bed | 2 Bath | 1,908 Sq Ft | Built 1980            Polk County
# 10                          Hillsborough County  (Sep 2019 - Jul 2023)
# 11    3 Bed | 2 Bath | 1,754 Sq Ft | Built 1977          Monroe County
# 12      3 Bed | 1 Bath | 984 Sq Ft | Built 1932      Palm Beach County
# 13      3 Bed | 1 Bath | 984 Sq Ft | Built 1932      Palm Beach County
# 14      2 Bed | 2 Bath | 855 Sq Ft | Built 2006      Palm Beach County
# 15    3 Bed | 2 Bath | 1,090 Sq Ft | Built 1967       Charlotte County
# 16    3 Bed | 2 Bath | 1,090 Sq Ft | Built 1967       Charlotte County
# 17                                 Comal County  (Oct 2018 - Jul 2023)
# 18                                 Comal County  (Oct 1999 - Jul 2023)
# 19  4 Bed | 2.5 Bath | 1,591 Sq Ft | Built 1971         Broward County
# 20      2 Bed | 1 Bath | 897 Sq Ft | Built 1964         Broward County
# 21                            Palm Beach County  (Jun 1996 - Jul 2023)
# 22    3 Bed | 2 Bath | 1,168 Sq Ft | Built 1993         Osceola County
# 23    3 Bed | 2 Bath | 1,040 Sq Ft | Built 1958         Brevard County
# 24  4 Bed | 1.5 Bath | 1,320 Sq Ft | Built 1959          Orange County
# 25    3 Bed | 2 Bath | 1,532 Sq Ft | Built 2019            Polk County
# 26                              Sarasota County  (Aug 2003 - Jul 2023)
# 27                        San Bernardino County  (Mar 2011 - Jul 2023)
# 28      3 Bed | 1 Bath | 988 Sq Ft | Built 1953      Miami-Dade County
# 29                               Hocking County  (May 1993 - Jul 2023)
# 30      2 Bed | 1 Bath | 672 Sq Ft | Built 1950        Franklin County
# 31    3 Bed | 1 Bath | 1,329 Sq Ft | Built 1951         Brevard County
# 32                                 Pasco County  (Feb 2005 - Jul 2023)
# 33                            Palm Beach County  (May 2005 - Jul 2023)
# 34    2 Bed | 1 Bath | 1,710 Sq Ft | Built 1965      Miami-Dade County
# 35    2 Bed | 1 Bath | 1,710 Sq Ft | Built 1965      Miami-Dade County
# 36      2 Bed | 1 Bath | 784 Sq Ft | Built 1951      Miami-Dade County
# 37    4 Bed | 2 Bath | 3,640 Sq Ft | Built 1952      Miami-Dade County
# 38    5 Bed | 3 Bath | 4,029 Sq Ft | Built 2002         Broward County
# 39    3 Bed | 2 Bath | 1,790 Sq Ft | Built 2007             Lee County
# 40  4 Bed | 2.5 Bath | 1,957 Sq Ft | Built 1964         Broward County
# 41    4 Bed | 2 Bath | 2,493 Sq Ft | Built 1970         Broward County
#
#         Living Time Period          Phone1 Phone1 Type          Phone2  \
# 0    (Apr 2011 - Jul 2023)  (352) 205-0927    Wireless  (352) 414-4295
# 1   Possible Primary Phone  (561) 502-6293    Wireless  (561) 737-4174
# 2    (Sep 2005 - Jul 2023)       Not found   Not found       Not found
# 3   Possible Primary Phone  (561) 707-5911    Wireless  (561) 686-0930
# 4    (Jan 1978 - Jul 2023)  (561) 667-2794    Wireless  (561) 667-2792
# 5    (Sep 2006 - Jul 2023)  (941) 493-2608    Landline  (941) 716-7163
# 6    (Jun 1975 - Jul 2023)  (813) 677-3682    Landline  (813) 671-8231
# 7    (Jun 1996 - Jul 2023)  (813) 805-7765    Landline  (813) 839-8268
# 8    (Mar 1991 - Jul 2023)  (813) 229-5973    Landline  (813) 888-6544
# 9    (Aug 2009 - Jul 2023)  (916) 698-2804    Wireless  (813) 229-5973
# 10  Possible Primary Phone  (813) 298-4426    Wireless  (813) 229-5973
# 11   (Jun 2002 - Jul 2023)  (305) 745-1618    Landline  (305) 394-3703
# 12   (Feb 2001 - Jul 2023)  (561) 848-2943    Landline       Not found
# 13   (Nov 2001 - Jul 2023)       Not found   Not found       Not found
# 14   (Feb 2019 - Jul 2023)  (561) 848-2943    Landline  (561) 444-3391
# 15   (Jun 1977 - Jul 2023)  (941) 505-8246    Landline  (941) 268-1236
# 16   (Apr 2010 - Jul 2023)       Not found   Not found       Not found
# 17               Not found       Not found   Not found       Not found
# 18  Possible Primary Phone  (941) 766-9434    Landline  (352) 223-7629
# 19   (Oct 1999 - Jul 2023)  (954) 970-6947    Landline  (954) 296-3077
# 20   (Mar 2002 - Jul 2023)  (954) 401-1072    Wireless  (954) 965-7158
# 21  Possible Primary Phone  (561) 985-1934    Wireless  (561) 996-3613
# 22   (Dec 2006 - Jul 2023)  (407) 590-7299    Wireless  (407) 390-9326
# 23   (Mar 1994 - Jul 2023)  (321) 421-7204    Landline  (407) 704-5894
# 24   (Apr 1992 - Jul 2023)  (407) 291-1372    Landline  (407) 292-7849
# 25   (Jan 2019 - Jul 2023)  (407) 850-6826    Landline  (407) 855-3776
# 26  Possible Primary Phone  (941) 323-7059    Wireless  (941) 423-3346
# 27  Possible Primary Phone  (831) 247-5788    Wireless  (941) 544-3455
# 28   (Jan 2006 - Jul 2023)  (305) 807-5441    Wireless  (305) 816-6434
# 29  Possible Primary Phone  (239) 217-2531    Wireless  (239) 995-1117
# 30   (Apr 1993 - Jul 2023)  (740) 385-7552    Landline  (614) 385-7552
# 31   (Nov 2007 - Jul 2023)  (321) 720-7624    Wireless  (321) 633-6405
# 32  Possible Primary Phone  (727) 375-8192    Landline  (727) 934-6612
# 33  Possible Primary Phone  (561) 445-1503    Wireless  (305) 552-9703
# 34   (Aug 1995 - Jul 2023)  (305) 551-4600    Landline  (786) 329-2228
# 35   (Dec 1995 - Jul 2023)       Not found   Not found       Not found
# 36   (Sep 1983 - Jul 2023)  (305) 696-4977    Landline  (305) 691-2557
# 37   (Mar 1979 - Jul 2023)  (786) 319-3420    Wireless  (305) 638-7003
# 38   (Oct 2002 - Jul 2023)  (954) 755-1686    Landline  (954) 688-6273
# 39   (Jan 2012 - Jul 2023)  (914) 420-8323    Wireless  (718) 572-4167
# 40   (Feb 1980 - Jul 2023)  (954) 826-2868    Wireless  (954) 731-3677
# 41   (Sep 2008 - Jul 2023)  (754) 422-9777    Wireless  (954) 530-8412
#
#    Phone2 Type          Phone3 Phone3 Type
# 0     Landline  (352) 347-2757    Landline
# 1     Landline  (561) 364-2437    Landline
# 2    Not found       Not found   Not found
# 3     Landline  (240) 988-1499    Wireless
# 4     Wireless  (561) 615-8241    Landline
# 5     Wireless  (941) 727-0059    Landline
# 6     Landline  (786) 286-1908    Wireless
# 7     Landline  (813) 837-7045    Landline
# 8     Landline  (352) 567-3931    Landline
# 9     Landline  (813) 391-6072    Wireless
# 10    Landline  (813) 276-1806    Landline
# 11    Wireless  (305) 292-0077    Landline
# 12   Not found       Not found   Not found
# 13   Not found       Not found   Not found
# 14        VOIP  (561) 281-2403    Wireless
# 15    Wireless  (941) 639-4093    Landline
# 16   Not found       Not found   Not found
# 17   Not found       Not found   Not found
# 18    Wireless       Not found   Not found
# 19    Wireless  (610) 489-4190    Landline
# 20    Landline  (386) 740-0944    Landline
# 21    Landline  (561) 596-3725    Wireless
# 22    Landline  (407) 348-2638    Landline
# 23    Wireless  (321) 299-8333    Wireless
# 24    Landline       Not found   Not found
# 25    Landline  (203) 574-3585    Landline
# 26    Landline  (717) 359-1982    Landline
# 27    Wireless  (941) 564-6771        VOIP
# 28        VOIP  (203) 715-3810    Wireless
# 29    Landline  (239) 656-4246    Landline
# 30    Landline       Not found   Not found
# 31    Landline       Not found   Not found
# 32    Landline       Not found   Not found
# 33    Landline  (352) 408-0530    Wireless
# 34    Wireless  (305) 553-1395    Landline
# 35   Not found       Not found   Not found
# 36    Landline  (786) 970-3910    Wireless
# 37    Landline  (305) 219-3161    Wireless
# 38        VOIP  (954) 648-4800    Wireless
# 39    Landline  (803) 474-4650    Landline
# 40    Landline  (954) 731-2432    Landline
# 41        VOIP  (954) 714-6707    Landline
